# %% [markdown]
# # 01 Descriptive And Eda
#
# Review generated descriptive statistics and correlations.
#
# This thin interface delegates computation to `src/heatwave_analysis` and the command-line pipeline.

# %%
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
assert (ROOT / 'results' / 'metadata' / 'run_metadata.json').exists(), 'Run make analysis first'
print((ROOT / 'results' / 'metadata' / 'run_metadata.json').read_text())
